# %% [markdown]
# ### Project1
# #### Project on IPL Data set
#
# - 1.Display the count of matches based on the year wise
#
# - 2.Plot a bar graph  no. of matches won by each team in the year  2011
#
# - 3.Print  ManOfMatch count of each player in  Hyderabad stadium

# %%
import pandas as pd
df =  pd.read_csv('datafiles/Match.csv')
df.shape
# Out:
# (637, 17)

# %%
df.head()
# Out:
#    Match_SK  match_id                        Team1  \
# 0         0    335987  Royal Challengers Bangalore
# 1         1    335988              Kings XI Punjab
# 2         2    335989             Delhi Daredevils
# 3         3    335990               Mumbai Indians
# 4         4    335991        Kolkata Knight Riders
#
#                          Team2 match_date  Season_Year  \
# 0        Kolkata Knight Riders  4/18/2008         2008
# 1          Chennai Super Kings  4/19/2008         2008
# 2             Rajasthan Royals  4/19/2008         2008
# 3  Royal Challengers Bangalore  4/20/2008         2008
# 4              Deccan Chargers  4/20/2008         2008
#
#                                    Venue_Name   City_Name Country_Name  \
# 0                       M Chinnaswamy Stadium   Bangalore        India
# 1  Punjab Cricket Association Stadium, Mohali  Chandigarh        India
# 2                            Feroz Shah Kotla       Delhi        India
# ...

# %% [markdown]
# - 1.Display the count of matches based on the year wise

# %% [markdown]
# - sort_index() - sorting based on index
# - sort_values() - sorting based on values

# %%
a = df['Season_Year'].value_counts().sort_index()
print(type(a))
pd.DataFrame(a)
# Out:
# <class 'pandas.core.series.Series'>
#       Season_Year
# 2008           58
# 2009           57
# 2010           60
# 2011           73
# 2012           74
# 2013           76
# 2014           60
# 2015           59
# 2016           60
# 2017           60

# %% [markdown]
# - 2.Plot a bar graph no. of matches won by each team in the year 2011

# %%
# b = df['match_winner'].value_counts()
# print(type(b))
# pd.DataFrame(b)

# %%
c=  df[df['Season_Year']==2011]
print(type(c))
c.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      Match_SK  match_id                 Team1                        Team2  \
# 175       175    501203   Chennai Super Kings        Kolkata Knight Riders
# 176       176    501204       Deccan Chargers             Rajasthan Royals
# 177       177    501205  Kochi Tuskers Kerala  Royal Challengers Bangalore
# 178       178    501206      Delhi Daredevils               Mumbai Indians
# 179       179    501207         Pune Warriors              Kings XI Punjab
#
#      match_date  Season_Year                                 Venue_Name  \
# 175  04-08-2011         2011            MA Chidambaram Stadium, Chepauk
# 176  04-09-2011         2011  Rajiv Gandhi International Stadium, Uppal
# 177  04-09-2011         2011                              Nehru Stadium
# 178  04-10-2011         2011                           Feroz Shah Kotla
# 179  04-10-2011         2011                 Dr DY Patil Sports Academy
#
# ...

# %%
d = c['match_winner'].value_counts()
print(type(d))
pd.DataFrame(d)
# Out:
# <class 'pandas.core.series.Series'>
#                              match_winner
# Chennai Super Kings                    11
# Mumbai Indians                         10
# Royal Challengers Bangalore            10
# Kolkata Knight Riders                   8
# Kings XI Punjab                         7
# Kochi Tuskers Kerala                    6
# Deccan Chargers                         6
# Rajasthan Royals                        6
# Pune Warriors                           4
# Delhi Daredevils                        4

# %% [markdown]
# l1= d.values.tolist()
# l1

# %% [markdown]
# l2=d.index.tolist()
# l2

# %%
import numpy as np
import  matplotlib.pyplot as plt

l1= d.values.tolist()
l2=d.index.tolist()

width = 0.70

plt.barh(l2,l1,color='green')
#plt.figure(figsize=(15,5))
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# - 3.Print ManOfMatch count of each player in Hyderabad stadium

# %%
e=  df[df['City_Name']=='Hyderabad']
print(type(e))
e.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     Match_SK  match_id            Team1                        Team2  \
# 6          6    335993  Deccan Chargers             Delhi Daredevils
# 8          8    335995  Deccan Chargers             Rajasthan Royals
# 17        17    336004  Deccan Chargers              Kings XI Punjab
# 20        20    336007  Deccan Chargers  Royal Challengers Bangalore
# 32        32    336019  Deccan Chargers        Kolkata Knight Riders
#
#     match_date  Season_Year                                 Venue_Name  \
# 6    4/22/2008         2008  Rajiv Gandhi International Stadium, Uppal
# 8    4/24/2008         2008  Rajiv Gandhi International Stadium, Uppal
# 17  05-01-2008         2008  Rajiv Gandhi International Stadium, Uppal
# 20   5/25/2008         2008  Rajiv Gandhi International Stadium, Uppal
# 32  05-11-2008         2008  Rajiv Gandhi International Stadium, Uppal
#
#     City_Name Country_Name            Toss_Winner  \
# ...

# %%
q= e['ManOfMach'].value_counts()
print(type(q))
pd.DataFrame(q)
# Out:
# <class 'pandas.core.series.Series'>
#                    ManOfMach
# DA Warner                  6
# DW Steyn                   3
# YK Pathan                  2
# A Mishra                   2
# V Sehwag                   2
# GH Vihari                  2
# SK Raina                   2
# SE Marsh                   1
# G Gambhir                  1
# R Vinay Kumar              1
# PA Patel                   1
# SC Ganguly                 1
# AT Rayudu                  1
# DJ Bravo                   1
# MR Marsh                   1
# AB Dinda                   1
# SK Trivedi                 1
# DJG Sammy                  1
# V Kohli                    1
# MJ McClenaghan             1
# Mandeep Singh              1
# B Kumar                    1
# CH Morris                  1
# Mustafizur Rahman          1
# WP Saha                    1
# UT Yadav                   1
# I Sharma                   1
# SL Malinga                 1
# PC Valthaty                1
